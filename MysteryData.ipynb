# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import scipy.io as sio

mat = sio.loadmat("/content/drive/MyDrive/raw_noteboooks/mysteryDataset.mat")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-67d0778f0d46> in <module>
#       1 import scipy.io as sio
#       2
# ----> 3 mat = sio.loadmat("/content/drive/MyDrive/raw_noteboooks/mysteryDataset.mat")
#
# /usr/local/lib/python3.7/dist-packages/scipy/io/matlab/mio.py in loadmat(file_name, mdict, appendmat, **kwargs)
#     224     with _open_file_context(file_name, appendmat) as f:
#     225         MR, _ = mat_reader_factory(f, **kwargs)
# --> 226         matfile_dict = MR.get_variables(variable_names)
#     227
#     228     if mdict is not None:
#
# /usr/local/lib/python3.7/dist-packages/scipy/io/matlab/mio5.py in get_variables(self, variable_names)
#     310         mdict['__globals__'] = []
#     311         while not self.end_of_stream():
# --> 312             hdr, next_position = self.read_var_header()
# ...
